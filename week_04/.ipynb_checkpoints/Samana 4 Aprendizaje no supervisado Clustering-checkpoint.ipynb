# %% [markdown]
# # Ejercicio de Cluster o Agrupamiento Kmeans
#
# ### Dado un conjunto de datos, se pretende agruparlos en clusters dependiendo de la distancia de cada elemento al centroide de cada grupo
#
# #### 1. Revisión del algoritmo
# ##### Dado un conjunto de datos X de dimensiones (10,2) implementaremos el algoritmo para determinar dos clusters, en donde los elementos tienen características similares

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import pandas as pd
from scipy.spatial import distance

# %%
# X Conjunto de datos de entrada. Dos características y 10 datos
X = np.array([[2,1],[3,10],[4,12],[18,10],[23,50],[65,65],[68,81],[63,72],[42,65],[58,100]])

plt.axis('equal')
plt.scatter(X[:,0],X[:,1])

# Iniciamos los centroides
ck = np.random.randint(np.min(X),np.max(X), size=(2, 2))

plt.scatter(ck[:,0],ck[:,1],s=100,marker='*')
plt.show()
print(ck[0,:],ck[1,:])
# Out:
# [35 78] [14 45]

# %%
# Calculamos las distancias de cada dato al centroide y reasignamos a los conjuntos C1 y C2
for iteration in range(5):
  C1 = []
  C2 = []
  i=0
  print(ck[0,:],ck[1,:])
  for x in X:
    dst1 = distance.euclidean(X[i,:], ck[0,:])
    dst2 = distance.euclidean(X[i,:], ck[1,:])

    if dst1 < dst2:
      C1.append(X[i,:])
    else: 
      C2.append(X[i,:])
    i = i+1

  print('iteration: ', iteration)

  AC1=np.array(C1)
  AC2=np.array(C2)

  plt.axis('equal')
  plt.scatter(ck[:,0],ck[:,1],s=100,marker='*')
  plt.scatter(AC1[:,0],AC1[:,1], label='True Position')
  plt.scatter(AC2[:,0],AC2[:,1], label='True Position')
  plt.show()

  # Actualizamos las coordenadas de los centroides
  ck[0,0] = np.mean(AC1[:,0])
  ck[0,1] = np.mean(AC1[:,1])

  ck[1,0] = np.mean(AC2[:,0])
  ck[1,1] = np.mean(AC2[:,1])
# Out:
# [35 78] [14 45]
# iteration:  0
# [59 76] [10 16]
# iteration:  1
# [59 76] [10 16]
# iteration:  2
# [59 76] [10 16]
# iteration:  3
# [59 76] [10 16]
# iteration:  4

# %% [markdown]
# ## Predicción
# #### Dado un nuevo dato xn, se asigna al conjunto C1 o C2 teniendo en cuenta la distancia
# #### del elemento a los centroides de cada grupo

# %%
# xn, nuevo dato
xn = (20,30)

# Distancia de xn a cada centroide
dst1 = distance.euclidean(xn, ck[0,:])
dst2 = distance.euclidean(xn, ck[1,:])

if dst1 < dst2:
  print('El dato Xn pertenece al cluster:{} con centroide {}'.format(1,ck[0,:]))
else:
  print('El dato Xn pertenece al cluster:{} con centroide {}'.format(2,ck[1,:]))

  plt.axis('equal')
  
  plt.scatter(xn[0],xn[1],s=100,marker='o')
  plt.scatter(ck[:,0],ck[:,1],s=100,marker='*')
  plt.scatter(AC1[:,0],AC1[:,1], label='True Position')
  plt.scatter(AC2[:,0],AC2[:,1], label='True Position')
  plt.show()
# Out:
# El dato Xn pertenece al cluster:2 con centroide [10 16]

# %% [markdown]
# # Ahora usaremos Scikit- Learn
# ## Usaremos un dataset propio de la libreria y el algoritmo kmeans
#
# ### Kmeans con Scikit Learn
# ### Realizaremos la predicción de dígitos en imágenes usando Kmeans y la librería Sklearn

# %%
from sklearn.datasets import load_digits
from sklearn.cluster import KMeans
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %% [markdown]
# #### Incluye 1797 datos, en grupos de imagenes de numeros de 8*8 en tamaño del píxel. La información almecenada es el número de píxeles de cada numero.

# %%
# vamos a dividir el data set en un conjunto de datos de entrenamiento y un conjunto de datos de prueba, 
# Por defecto la división sera 75% y 25 % prueba.

from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(digits.data, digits.target,random_state=0,stratify = digits.target)

# %% [markdown]
# # haremos el entrenamiento indicando 10 cluster, por que son 10 dígitos usando el segmento de entrenamiento.

# %%
kmeans = KMeans(n_clusters=10, random_state=0).fit(Xtrain)

# %% [markdown]
# ## Encontraremos los centroides para cada una de las clases, y seran 64 datos para cada centroide en una lista de datos.

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.00000000e+00,  2.98507463e-02,  4.18656716e+00,
#          1.31492537e+01,  1.11343284e+01,  2.94776119e+00,
#          3.73134328e-02,  4.16333634e-17,  0.00000000e+00,
#          8.95522388e-01,  1.24701493e+01,  1.31716418e+01,
#          1.12835821e+01,  1.13805970e+01,  1.03731343e+00,
#          2.77555756e-17,  4.33680869e-19,  3.79104478e+00,
#          1.39925373e+01,  5.29104478e+00,  2.20895522e+00,
#          1.22686567e+01,  3.64179104e+00,  1.38777878e-17,
#          0.00000000e+00,  5.23880597e+00,  1.25746269e+01,
#          2.17910448e+00,  2.98507463e-01,  9.31343284e+00,
#          6.34328358e+00, -8.67361738e-19,  0.00000000e+00,
#          5.90298507e+00,  1.14402985e+01,  8.95522388e-01,
#          1.49253731e-02,  9.12686567e+00,  7.04477612e+00,
#          0.00000000e+00,  3.46944695e-18,  3.52985075e+00,
#          1.31940299e+01,  1.69402985e+00,  1.46268657e+00,
#          1.15149254e+01,  5.71641791e+00,  1.38777878e-17,
#          1.73472348e-18,  8.58208955e-01,  1.32686567e+01,
#          9.87313433e+00,  1.04477612e+01,  1.32611940e+01,
#          2.44029851e+00,  2.98507463e-02,  2.16840434e-19,
#          7.46268657e-03,  4.26865672e+00,  1.35820896e+01,
#          1.33059701e+01,  5.37313433e+00,  3.28358209e-01,
#          2.23880597e-02],
#        [ 0.00000000e+00,  1.39393939e-01,  4.09090909e+00,
#          1.18484848e+01,  1.23454545e+01,  5.37575758e+00,
#          4.54545455e-01,  4.16333634e-17,  1.21212121e-02,
#          8.60606061e-01,  8.13939394e+00,  1.36121212e+01,
#          1.27090909e+01,  1.00909091e+01,  1.61818182e+00,
#          0.00000000e+00,  6.50521303e-19,  1.12121212e+00,
#          8.16363636e+00,  1.19636364e+01,  1.25030303e+01,
#          9.89090909e+00,  1.06060606e+00,  2.08166817e-17,
#          0.00000000e+00,  8.84848485e-01,  7.08484848e+00,
#          1.43151515e+01,  1.43454545e+01,  5.04242424e+00,
#          2.18181818e-01, -4.33680869e-19,  0.00000000e+00,
#          7.87878788e-01,  8.15757576e+00,  1.49515152e+01,
#          1.29393939e+01,  2.36363636e+00,  1.21212121e-02,
#          0.00000000e+00,  2.60208521e-18,  1.24242424e+00,
#          1.08303030e+01,  1.20121212e+01,  1.19696970e+01,
#          4.13333333e+00,  1.63636364e-01,  1.38777878e-17,
#          1.81818182e-02,  9.45454545e-01,  1.00848485e+01,
#          1.17030303e+01,  1.18242424e+01,  5.35757576e+00,
#          0.00000000e+00, -8.67361738e-19,  8.40579710e-01,
#          2.23188406e+00,  3.13043478e+00,  1.09710145e+01,
#          1.21594203e+01,  1.21739130e+00,  0.00000000e+00,
#         -4.33680869e-19,  4.34782609e-02,  1.44927536e-01,
#          2.42028986e+00,  1.21594203e+01,  1.07826087e+01,
#          1.39130435e+00,  0.00000000e+00,  2.16840434e-19,
#          0.00000000e+00,  0.00000000e+00,  2.13043478e+00,
#          1.10000000e+01,  1.00289855e+01,  1.42028986e+00,
#         -1.11022302e-16],
#        [ 0.00000000e+00,  2.13740458e-01,  5.51908397e+00,
#          1.33511450e+01,  1.43358779e+01,  1.06335878e+01,
#          4.38167939e+00,  5.03816794e-01,  0.00000000e+00,
#          1.29770992e+00,  1.10229008e+01,  1.13435115e+01,
#          1.10152672e+01,  1.25496183e+01,  4.38931298e+00,
#          1.37404580e-01,  6.50521303e-19,  8.24427481e-01,
#          4.48854962e+00,  1.90839695e+00,  7.83969466e+00,
#          1.16488550e+01,  2.29007634e+00,  2.29007634e-02,
#          0.00000000e+00,  6.87022901e-01,  4.26717557e+00,
#          7.02290076e+00,  1.29770992e+01,  1.22519084e+01,
#          5.09923664e+00,  7.63358779e-03,  0.00000000e+00,
#          1.64122137e+00,  9.76335878e+00,  1.42366412e+01,
#          1.50458015e+01,  1.09465649e+01,  4.43511450e+00,
#          0.00000000e+00,  2.60208521e-18,  1.05343511e+00,
#          5.66412214e+00,  1.24580153e+01,  1.05572519e+01,
#          3.44274809e+00,  5.80152672e-01,  1.38777878e-17,
#          1.30104261e-18,  9.16030534e-02,  3.37404580e+00,
#          1.26106870e+01,  5.51908397e+00,  2.51908397e-01,
#          0.00000000e+00,  1.38777878e-16,  3.25260652e-19,
#          1.52671756e-01,  7.07633588e+00,  1.16259542e+01,
#          2.00000000e+00,  6.87022901e-02,  1.33226763e-15,
#         -5.55111512e-17]])

# %% [markdown]
# ## Vamos a graficar esos centroides, hacemos un reshape para verlos en forma de imagenes de 8x8 y se nos muestra el centroide para cada cluster.
# ### No están ordenados por que el sistema es no supervisado y no etiqueta los conjuntos.

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
numbers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, number in zip(ax.flat, numbers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(number, interpolation='nearest', cmap=plt.cm.binary)

# %% [markdown]
# # vamos a predecir usando los datos de prueba, para indicar a que cluster corresponde.

# %%
ypred = kmeans.predict(Xtest)

# %%
for i in range(0,10):

    row = np.where(ypred==i)[0]  # las filas en ypred que corresponden al cluster i
    num = row.shape[0]       #  Elementos de cada cluster
    r = np.floor(num/65)    #  Numero de filas para las figuras en el plot

    print("cluster "+str(i))
    print(str(num)+" elementos")    
    
    plt.figure(figsize=(25,5))
    for k in range(0, num):
        plt.subplot(1, 65, 1)
        image = Xtest[row[k], ]
        image = image.reshape(8, 8)
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.show()
# Out:
# cluster 0
# 45 elementos
# cluster 1
# 58 elementos
# cluster 2
# 45 elementos
# cluster 3
# 44 elementos
# cluster 4
# 41 elementos
# cluster 5
# 38 elementos
# cluster 6
# 38 elementos
# cluster 7
# 61 elementos
# cluster 8
# 28 elementos
# cluster 9
# 52 elementos

# %% [markdown]
# ## Dataset de plantas IRIS

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Cargamos dataset de iris
iris = datasets.load_iris()

# Imprimimos especies y características
print(iris.target_names)
print(iris.feature_names)

# Dividimos datos para entrenamiento y prueba
Xtrain, Xtest, ytrain, ytest = train_test_split(iris.data, iris.target,random_state=8,stratify = iris.target)
# Out:
# ['setosa' 'versicolor' 'virginica']
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# Creamos dataframe para los datos de entrenamiento y pruebas
import pandas as pd
X_test=pd.DataFrame({
    'sepal length':Xtest[:,0],
    'sepal width':Xtest[:,1],
    'petal length':Xtest[:,2],
    'petal width':Xtest[:,3],
    'species': ytest
})
X_train=pd.DataFrame({
    'sepal length':Xtrain[:,0],
    'sepal width':Xtrain[:,1],
    'petal length':Xtrain[:,2],
    'petal width':Xtrain[:,3],
    'species': ytrain
})


X_train.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           6.2          3.4           5.4          2.3        2
# 1           6.7          3.3           5.7          2.5        2
# 2           5.8          4.0           1.2          0.2        0
# 3           5.7          3.0           4.2          1.2        1
# 4           6.3          2.5           5.0          1.9        2
# 5           5.2          4.1           1.5          0.1        0
# 6           5.0          3.0           1.6          0.2        0
# 7           4.8          3.0           1.4          0.3        0
# 8           6.9          3.2           5.7          2.3        2
# 9           6.9          3.1           5.4          2.1        2

# %%
from sklearn.cluster import KMeans

# Se aplica el algoritmo y se encuentra los centroides de los grupos
kmeans = KMeans(n_clusters=3, random_state=0).fit(X_train.drop(["species"],axis = 1))

# %%
kmeans.cluster_centers_
# Out:
# array([[5.01621622, 3.43243243, 1.46216216, 0.23783784],
#        [5.922     , 2.778     , 4.444     , 1.452     ],
#        [6.904     , 3.116     , 5.852     , 2.116     ]])

# %%
import statistics as stat
import numpy as np

# Realizamos la predicción con los datos de prueba
y_pred = kmeans.predict(X_test.drop(["species"],axis = 1))

for i in range(0,3):

    row = np.where(y_pred==i)[0]  # Filas en y_pred que corresponden con el cluster i
    num = row.shape[0]       #  Elementos de cada cluster
    r = np.floor(num/10)    #  Numero de filas para las figuras en el plot

    print("cluster "+str(i))
    print(str(num)+" elementos")

    templist = []
    for k in range(0, num):
        templist.append(X_test.iloc[row[k], ].species)
    
    print('Clase asociada al cluster:',stat.mode(templist))
# Out:
# cluster 0
# 13 elementos
# Clase asociada al cluster: 0.0
# cluster 1
# 14 elementos
# Clase asociada al cluster: 1.0
# cluster 2
# 11 elementos
# Clase asociada al cluster: 2.0

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


ax.view_init(15, 40)

ax.scatter(X_test['sepal length'], X_test['sepal width'],X_test['petal length'],c=y_pred,cmap='viridis')
ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,2],c ='blue',s=200,alpha = 0.5)

plt.show()

# %%
y_pred
# Out:
# array([2, 2, 1, 1, 0, 1, 0, 1, 0, 1, 2, 2, 0, 1, 1, 1, 0, 0, 2, 1, 1, 2,
#        0, 1, 1, 0, 0, 0, 0, 1, 0, 2, 0, 1, 2, 2, 2, 2])

# %%
ytest
# Out:
# array([2, 2, 1, 1, 0, 1, 0, 1, 0, 1, 2, 2, 0, 1, 1, 1, 0, 0, 2, 1, 2, 2,
#        0, 1, 2, 0, 0, 0, 0, 1, 0, 2, 0, 1, 1, 2, 2, 2])

# %% [markdown]
# # Matriz de confusión : Se usa como metrica de desempeño, compara la predicción con las salidas reales, en la diagonal principal se espera el mayor número de aciertos.

# %%
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(ytest,y_pred)
print(matriz)
# Out:
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
